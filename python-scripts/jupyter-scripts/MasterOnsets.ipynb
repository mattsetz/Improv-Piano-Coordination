# %%
import pandas as pd
import numpy as np
from glob import glob

# %%
summary = pd.read_csv('../summary.csv')
summary.head()
# Out:
#   Subject  Trial condition
# 0       a      1      Real
# 1       a      2      Real
# 2       a      3      Real
# 3       a      4      Real
# 4      aa      1      Real

# %%
##########################################################
# Merge Onset data from all trials into one dataframe
##########################################################

from glob import glob

onset_files = glob('../Pipeline/onsets/*.csv')

# iterate through every file, add onsets to master_onsets
master_onsets = pd.DataFrame()

for f in onset_files:
    print(f)
    # get info
    fname = f.split('/')[-1]
    if (fname.count('.') != 3): continue # weed out solo tracks
    personCombo = fname.split('.')[1]
    person_trial = fname.split('.')[2]
    name = fname.replace('.csv','')
    other_person = personCombo.replace(person_trial,'')
    cond = summary[(summary.Trial == int(person_trial[-1]))&
                    (summary.Subject==person_trial[:-1])].condition.values[0]
        
    # get onsets
    onsets = pd.read_csv(f, index_col = False)
    onsets['personCombo'] = personCombo
    onsets['person_trial'] = person_trial
    onsets['name'] = name
    onsets['other_person'] = other_person
    onsets['cond'] = cond
    print(len(onsets))
    print(len(master_onsets))
    master_onsets = master_onsets.append(onsets)
# Out:
# ../Pipeline/onsets/t1.a1b1.a1.csv
# 1078
# 0
# ../Pipeline/onsets/t1.a1b1.b1.csv
# 1207
# 1078
# ../Pipeline/onsets/t1.aa1bb1.aa1.csv
# 2393
# 2285
# ../Pipeline/onsets/t1.aa1bb1.bb1.csv
# 1766
# 4678
# ../Pipeline/onsets/t1.c1d1.c1.csv
# 1130
# 6444
# ../Pipeline/onsets/t1.c1d1.d1.csv
# 2294
# 7574
# ../Pipeline/onsets/t1.e1d1.e1.csv
# 884
# 9868
# ../Pipeline/onsets/t1.g1h1.g1.csv
# 1521
# 10752
# ../Pipeline/onsets/t1.g1h1.h1.csv
# 1205
# 12273
# ../Pipeline/onsets/t1.i1h1.i1.csv
# 1329
# 13478
# ../Pipeline/onsets/t1.k1l1.k1.csv
# 489
# 14807
# ../Pipeline/onsets/t1.k1l1.l1.csv
# 553
# 15296
# ../Pipeline/onsets/t1.m1l1.m1.csv
# 832
# 15849
# ../Pipeline/onsets/t1.o1p1.o1.csv
# 1061
# 16681
# ../Pipeline/onsets/t1.o1p1.p1.csv
# 1393
# 17742
# ../Pipeline/onsets/t1.q1p1.q1.csv
# 1087
# 19135
# ../Pipeline/onsets/t1.s1t1.s1.csv
# 416
# 20222
# ../Pipeline/onsets/t1.s1t1.t1.csv
# 171
# 20638
# ../Pipeline/onsets/t1.u1t1.u1.csv
# 314
# 20809
# ../Pipeline/onsets/t1.w1x1.w1.csv
# 139
# 21123
# ../Pipeline/onsets/t1.w1x1.x1.csv
# 248
# 21262
# ../Pipeline/onsets/t1.y1x1.y1.csv
# 361
# 21510
# ../Pipeline/onsets/t10.aa7bb7.aa7.csv
# 2383
# 21871
# ../Pipeline/onsets/t10.aa7bb7.bb7.csv
# 1665
# 24254
# ../Pipeline/onsets/t10.c7a4.c7.csv
# 2334
# 25919
# ../Pipeline/onsets/t10.e7f7.e7.csv
# 1905
# 28253
# ../Pipeline/onsets/t10.e7f7.f7.csv
# 2935
# 30158
# ../Pipeline/onsets/t10.g7h7.g7.csv
# 1957
# 33093
# ../Pipeline/onsets/t10.g7h7.h7.csv
# 1902
# 35050
# ../Pipeline/onsets/t10.i7h7.i7.csv
# 1191
# 36952
# ../Pipeline/onsets/t10.k7l7.k7.csv
# 2766
# 38143
# ../Pipeline/onsets/t10.k7l7.l7.csv
# 2800
# 40909
# ../Pipeline/onsets/t10.m7l7.m7.csv
# 2010
# 43709
# ../Pipeline/onsets/t10.q7r7.q7.csv
# 2490
# 45719
# ../Pipeline/onsets/t10.q7r7.r7.csv
# 1732
# 48209
# ../Pipeline/onsets/t10.s7t7.s7.csv
# 677
# 49941
# ../Pipeline/onsets/t10.s7t7.t7.csv
# 454
# 50618
# ../Pipeline/onsets/t10.u7t7.u7.csv
# 603
# 51072
# ../Pipeline/onsets/t10.w7x7.w7.csv
# 3267
# 51675
# ../Pipeline/onsets/t10.w7x7.x7.csv
# 1918
# 54942
# ../Pipeline/onsets/t11.b4d7.d7.csv
# 2773
# 56860
# ../Pipeline/onsets/t11.g7j7.j7.csv
# 1786
# 59633
# ../Pipeline/onsets/t11.k7n7.n7.csv
# 4177
# 61419
# ../Pipeline/onsets/t11.s7v7.v7.csv
# 799
# 65596
# ../Pipeline/onsets/t2.a2b2.a2.csv
# 1173
# 66395
# ../Pipeline/onsets/t2.a2b2.b2.csv
# 1515
# 67568
# ../Pipeline/onsets/t2.aa2z2.aa2.csv
# 1718
# 69083
# ../Pipeline/onsets/t2.c1f1.f1.csv
# 1808
# 70801
# ../Pipeline/onsets/t2.c2b1.c2.csv
# 1185
# 72609
# ../Pipeline/onsets/t2.g1j1.j1.csv
# 1007
# 73794
# ../Pipeline/onsets/t2.g2f2.g2.csv
# 1032
# 74801
# ../Pipeline/onsets/t2.k1n1.n1.csv
# 724
# 75833
# ../Pipeline/onsets/t2.k2j2.k2.csv
# 1514
# 76557
# ../Pipeline/onsets/t2.o1r1.r1.csv
# 817
# 78071
# ../Pipeline/onsets/t2.o2n2.o2.csv
# 1086
# 78888
# ../Pipeline/onsets/t2.s1v1.v1.csv
# 510
# 79974
# ../Pipeline/onsets/t2.s2r2.s2.csv
# 1123
# 80484
# ../Pipeline/onsets/t2.w1z1.z1.csv
# 589
# 81607
# ../Pipeline/onsets/t2.w2v2.w2.csv
# 1294
# 82196
# ../Pipeline/onsets/t3.a1d2.d2.csv
# 1356
# 83490
# ../Pipeline/onsets/t3.a3b3.a3.csv
# 1100
# 84846
# ../Pipeline/onsets/t3.a3b3.b3.csv
# 1801
# 85946
# ../Pipeline/onsets/t3.e2f2.e2.csv
# 973
# 87747
# ../Pipeline/onsets/t3.e2f2.f2.csv
# 1235
# 88720
# ../Pipeline/onsets/t3.e2h2.h2.csv
# 633
# 89955
# ../Pipeline/onsets/t3.i2j2.i2.csv
# 1916
# 90588
# ../Pipeline/onsets/t3.i2j2.j2.csv
# 2193
# 92504
# ../Pipeline/onsets/t3.i2l2.l2.csv
# 2050
# 94697
# ../Pipeline/onsets/t3.m2n2.m2.csv
# 620
# 96747
# ../Pipeline/onsets/t3.m2n2.n2.csv
# 940
# 97367
# ../Pipeline/onsets/t3.m2p2.p2.csv
# 78
# 98307
# ../Pipeline/onsets/t3.q2r2.q2.csv
# 4581
# 98385
# ../Pipeline/onsets/t3.q2r2.r2.csv
# 1886
# 102966
# ../Pipeline/onsets/t3.q2t2.t2.csv
# 1682
# 104852
# ../Pipeline/onsets/t3.u2v2.u2.csv
# 1260
# 106534
# ../Pipeline/onsets/t3.u2v2.v2.csv
# 1943
# 107794
# ../Pipeline/onsets/t3.u2x2.x2.csv
# 798
# 109737
# ../Pipeline/onsets/t3.y2bb2.bb2.csv
# 1411
# 110535
# ../Pipeline/onsets/t3.y2z2.y2.csv
# 2247
# 111946
# ../Pipeline/onsets/t3.y2z2.z2.csv
# 924
# 114193
# ../Pipeline/onsets/t4.a4b4.a4.csv
# 3240
# 115117
# ../Pipeline/onsets/t4.a4b4.b4.csv
# 2260
# 118357
# ../Pipeline/onsets/t4.aa3bb3.aa3.csv
# 1057
# 120617
# ../Pipeline/onsets/t4.aa3bb3.bb3.csv
# 793
# 121674
# ../Pipeline/onsets/t4.c3d3.c3.csv
# 933
# 122467
# ../Pipeline/onsets/t4.c3d3.d3.csv
# 1907
# 123400
# ../Pipeline/onsets/t4.e3d3.e3.csv
# 1035
# 125307
# ../Pipeline/onsets/t4.g3h3.g3.csv
# 271
# 126342
# ../Pipeline/onsets/t4.g3h3.h3.csv
# 505
# 126613
# ../Pipeline/onsets/t4.i3h3.i3.csv
# 571
# 127118
# ../Pipeline/onsets/t4.k3l3.k3.csv
# 2254
# 127689
# ../Pipeline/onsets/t4.k3l3.l3.csv
# 2562
# 129943
# ../Pipeline/onsets/t4.m3l3.m3.csv
# 2511
# 132505
# ../Pipeline/onsets/t4.o3p3.o3.csv
# 1495
# 135016
# ../Pipeline/onsets/t4.o3p3.p3.csv
# 1424
# 136511
# ../Pipeline/onsets/t4.q3p3.q3.csv
# 2397
# 137935
# ../Pipeline/onsets/t4.s3t3.s3.csv
# 2322
# 140332
# ../Pipeline/onsets/t4.s3t3.t3.csv
# 1825
# 142654
# ../Pipeline/onsets/t4.u3t3.u3.csv
# 1267
# 144479
# ../Pipeline/onsets/t4.w3x3.w3.csv
# 1214
# 145746
# ../Pipeline/onsets/t4.w3x3.x3.csv
# 1280
# 146960
# ../Pipeline/onsets/t4.y3x3.y3.csv
# 1735
# 148240
# ../Pipeline/onsets/t5.aa4z4.aa4.csv
# 827
# 149975
# ../Pipeline/onsets/t5.c3f3.f3.csv
# 1755
# 150802
# ../Pipeline/onsets/t5.c4a2.c4.csv
# 1342
# 152557
# ../Pipeline/onsets/t5.g3j3.j3.csv
# 350
# 153899
# ../Pipeline/onsets/t5.g4f4.g4.csv
# 1763
# 154249
# ../Pipeline/onsets/t5.k3n3.n3.csv
# 1297
# 156012
# ../Pipeline/onsets/t5.k4j4.k4.csv
# 1238
# 157309
# ../Pipeline/onsets/t5.o3r3.r3.csv
# 1103
# 158547
# ../Pipeline/onsets/t5.o4n4.o4.csv
# 2169
# 159650
# ../Pipeline/onsets/t5.s3v3.v3.csv
# 2659
# 161819
# ../Pipeline/onsets/t5.s4r4.s4.csv
# 969
# 164478
# ../Pipeline/onsets/t5.w3z3.z3.csv
# 989
# 165447
# ../Pipeline/onsets/t5.w4v4.w4.csv
# 4378
# 166436
# ../Pipeline/onsets/t6.b2d4.d4.csv
# 2544
# 170814
# ../Pipeline/onsets/t6.e4f4.e4.csv
# 1568
# 173358
# ../Pipeline/onsets/t6.e4f4.f4.csv
# 3315
# 174926
# ../Pipeline/onsets/t6.e4h4.h4.csv
# 950
# 178241
# ../Pipeline/onsets/t6.i4j4.i4.csv
# 1637
# 179191
# ../Pipeline/onsets/t6.i4j4.j4.csv
# 2093
# 180828
# ../Pipeline/onsets/t6.i4l4.l4.csv
# 1573
# 182921
# ../Pipeline/onsets/t6.m4n4.m4.csv
# 1522
# 184494
# ../Pipeline/onsets/t6.m4n4.n4.csv
# 1781
# 186016
# ../Pipeline/onsets/t6.m4p4.p4.csv
# 1157
# 187797
# ../Pipeline/onsets/t6.q4r4.q4.csv
# 2000
# 188954
# ../Pipeline/onsets/t6.q4r4.r4.csv
# 1030
# 190954
# ../Pipeline/onsets/t6.q4t4.t4.csv
# 415
# 191984
# ../Pipeline/onsets/t6.u4v4.u4.csv
# 1297
# 192399
# ../Pipeline/onsets/t6.u4v4.v4.csv
# 2169
# 193696
# ../Pipeline/onsets/t6.u4x4.x4.csv
# 410
# 195865
# ../Pipeline/onsets/t6.y4bb4.bb4.csv
# 1380
# 196275
# ../Pipeline/onsets/t6.y4z4.y4.csv
# 1732
# 197655
# ../Pipeline/onsets/t6.y4z4.z4.csv
# 936
# 199387
# ../Pipeline/onsets/t7.aa5bb5.aa5.csv
# 986
# 200323
# ../Pipeline/onsets/t7.aa5bb5.bb5.csv
# 1167
# 201309
# ../Pipeline/onsets/t7.c5d5.c5.csv
# 1586
# 202476
# ../Pipeline/onsets/t7.c5d5.d5.csv
# 2851
# 204062
# ../Pipeline/onsets/t7.e5d5.e5.csv
# 1225
# 206913
# ../Pipeline/onsets/t7.g5h5.g5.csv
# 1359
# 208138
# ../Pipeline/onsets/t7.g5h5.h5.csv
# 1207
# 209497
# ../Pipeline/onsets/t7.i5h5.i5.csv
# 1286
# 210704
# ../Pipeline/onsets/t7.k5l5.k5.csv
# 1472
# 211990
# ../Pipeline/onsets/t7.k5l5.l5.csv
# 2579
# 213462
# ../Pipeline/onsets/t7.m5l5.m5.csv
# 1917
# 216041
# ../Pipeline/onsets/t7.o5p5.o5.csv
# 2016
# 217958
# ../Pipeline/onsets/t7.o5p5.p5.csv
# 1144
# 219974
# ../Pipeline/onsets/t7.q5p5.q5.csv
# 2564
# 221118
# ../Pipeline/onsets/t7.s5t5.s5.csv
# 2389
# 223682
# ../Pipeline/onsets/t7.s5t5.t5.csv
# 2168
# 226071
# ../Pipeline/onsets/t7.u5t5.u5.csv
# 1638
# 228239
# ../Pipeline/onsets/t7.w5x5.w5.csv
# 493
# 229877
# ../Pipeline/onsets/t7.w5x5.x5.csv
# 1097
# 230370
# ../Pipeline/onsets/t7.y5x5.y5.csv
# 1717
# 231467
# ../Pipeline/onsets/t8.aa6z6.aa6.csv
# 803
# 233184
# ../Pipeline/onsets/t8.c5f5.f5.csv
# 2053
# 233987
# ../Pipeline/onsets/t8.c6a3.c6.csv
# 916
# 236040
# ../Pipeline/onsets/t8.g5j5.j5.csv
# 1200
# 236956
# ../Pipeline/onsets/t8.g6f6.g6.csv
# 1234
# 238156
# ../Pipeline/onsets/t8.k5n5.n5.csv
# 2357
# 239390
# ../Pipeline/onsets/t8.k6j6.k6.csv
# 1641
# 241747
# ../Pipeline/onsets/t8.o5r5.r5.csv
# 1128
# 243388
# ../Pipeline/onsets/t8.o6n6.o6.csv
# 3938
# 244516
# ../Pipeline/onsets/t8.s5v5.v5.csv
# 2230
# 248454
# ../Pipeline/onsets/t8.s6r6.s6.csv
# 1318
# 250684
# ../Pipeline/onsets/t8.w5z5.z5.csv
# 688
# 252002
# ../Pipeline/onsets/t8.w6v6.w6.csv
# 2120
# 252690
# ../Pipeline/onsets/t9.b3d6.d6.csv
# 2225
# 254810
# ../Pipeline/onsets/t9.e6f6.e6.csv
# 1153
# 257035
# ../Pipeline/onsets/t9.e6f6.f6.csv
# 1347
# 258188
# ../Pipeline/onsets/t9.e6h6.h6.csv
# 1053
# 259535
# ../Pipeline/onsets/t9.i6j6.i6.csv
# 1067
# 260588
# ../Pipeline/onsets/t9.i6j6.j6.csv
# 1381
# 261655
# ../Pipeline/onsets/t9.i6l6.l6.csv
# 1316
# 263036
# ../Pipeline/onsets/t9.m6n6.m6.csv
# 1690
# 264352
# ../Pipeline/onsets/t9.m6n6.n6.csv
# 1659
# 266042
# ../Pipeline/onsets/t9.m6p6.p6.csv
# 2938
# 267701
# ../Pipeline/onsets/t9.q6r6.q6.csv
# 1835
# 270639
# ../Pipeline/onsets/t9.q6r6.r6.csv
# 1004
# 272474
# ../Pipeline/onsets/t9.q6t6.t6.csv
# 559
# 273478
# ../Pipeline/onsets/t9.u6v6.u6.csv
# 3762
# 274037
# ../Pipeline/onsets/t9.u6v6.v6.csv
# 4142
# 277799
# ../Pipeline/onsets/t9.u6x6.x6.csv
# 3384
# 281941
# ../Pipeline/onsets/t9.y6bb6.bb6.csv
# 2122
# 285325
# ../Pipeline/onsets/t9.y6z6.y6.csv
# 1679
# 287447
# ../Pipeline/onsets/t9.y6z6.z6.csv
# 1298
# 289126

# %%
###########################
# Generate Asyncs
###########################

import numpy as np
master_asyncs = pd.DataFrame()

# generate asyncs
MIN_THRESH = 0.100 # 100 ms window
for p in np.unique(master_onsets.person_trial):
    print(p)
    onsets_p = master_onsets[master_onsets.person_trial==p]
    other_person = np.unique(onsets_p.other_person)[0]
    onsets_other = master_onsets[master_onsets.person_trial==other_person]
    
    for i in range(len(onsets_p)):
        if (i % 1000 ==0): print(str(i)+'/'+str(len(onsets_p)))
        onset_i = onsets_p.iloc[i]
        near_onsets = onsets_other[abs(onset_i.time-onsets_other.time)<MIN_THRESH]
        
        asyncs_i = pd.DataFrame({'cond': onset_i.cond,
                                 'asyncs': onset_i.time-near_onsets.time,})
        master_asyncs = master_asyncs.append(asyncs_i)
# Out:
# a1
# 0/1078
# 1000/1078
# a2
# 0/1173
# 1000/1173
# a3
# 0/1100
# 1000/1100
# a4
# 0/3240
# 1000/3240
# 2000/3240
# 3000/3240
# aa1
# 0/2393
# 1000/2393
# 2000/2393
# aa2
# 0/1718
# 1000/1718
# aa3
# 0/1057
# 1000/1057
# aa4
# 0/827
# aa5
# 0/986
# aa6
# 0/803
# aa7
# 0/2383
# 1000/2383
# 2000/2383
# b1
# 0/1207
# 1000/1207
# b2
# 0/1515
# 1000/1515
# b3
# 0/1801
# 1000/1801
# b4
# 0/2260
# 1000/2260
# 2000/2260
# bb1
# 0/1766
# 1000/1766
# bb2
# 0/1411
# 1000/1411
# bb3
# 0/793
# bb4
# 0/1380
# 1000/1380
# bb5
# 0/1167
# 1000/1167
# bb6
# 0/2122
# 1000/2122
# 2000/2122
# bb7
# 0/1665
# 1000/1665
# c1
# 0/1130
# 1000/1130
# c2
# 0/1185
# 1000/1185
# c3
# 0/933
# c4
# 0/1342
# 1000/1342
# c5
# 0/1586
# 1000/1586
# c6
# 0/916
# c7
# 0/2334
# 1000/2334
# 2000/2334
# d1
# 0/2294
# 1000/2294
# 2000/2294
# d2
# 0/1356
# 1000/1356
# d3
# 0/1907
# 1000/1907
# d4
# 0/2544
# 1000/2544
# 2000/2544
# d5
# 0/2851
# 1000/2851
# 2000/2851
# d6
# 0/2225
# 1000/2225
# 2000/2225
# d7
# 0/2773
# 1000/2773
# 2000/2773
# e1
# 0/884
# e2
# 0/973
# e3
# 0/1035
# 1000/1035
# e4
# 0/1568
# 1000/1568
# e5
# 0/1225
# 1000/1225
# e6
# 0/1153
# 1000/1153
# e7
# 0/1905
# 1000/1905
# f1
# 0/1808
# 1000/1808
# f2
# 0/1235
# 1000/1235
# f3
# 0/1755
# 1000/1755
# f4
# 0/3315
# 1000/3315
# 2000/3315
# 3000/3315
# f5
# 0/2053
# 1000/2053
# 2000/2053
# f6
# 0/1347
# 1000/1347
# f7
# 0/2935
# 1000/2935
# 2000/2935
# g1
# 0/1521
# 1000/1521
# g2
# 0/1032
# 1000/1032
# g3
# 0/271
# g4
# 0/1763
# 1000/1763
# g5
# 0/1359
# 1000/1359
# g6
# 0/1234
# 1000/1234
# g7
# 0/1957
# 1000/1957
# h1
# 0/1205
# 1000/1205
# h2
# 0/633
# h3
# 0/505
# h4
# 0/950
# h5
# 0/1207
# 1000/1207
# h6
# 0/1053
# 1000/1053
# h7
# 0/1902
# 1000/1902
# i1
# 0/1329
# 1000/1329
# i2
# 0/1916
# 1000/1916
# i3
# 0/571
# i4
# 0/1637
# 1000/1637
# i5
# 0/1286
# 1000/1286
# i6
# 0/1067
# 1000/1067
# i7
# 0/1191
# 1000/1191
# j1
# 0/1007
# 1000/1007
# j2
# 0/2193
# 1000/2193
# 2000/2193
# j3
# 0/350
# j4
# 0/2093
# 1000/2093
# 2000/2093
# j5
# 0/1200
# 1000/1200
# j6
# 0/1381
# 1000/1381
# j7
# 0/1786
# 1000/1786
# k1
# 0/489
# k2
# 0/1514
# 1000/1514
# k3
# 0/2254
# 1000/2254
# 2000/2254
# k4
# 0/1238
# 1000/1238
# k5
# 0/1472
# 1000/1472
# k6
# 0/1641
# 1000/1641
# k7
# 0/2766
# 1000/2766
# 2000/2766
# l1
# 0/553
# l2
# 0/2050
# 1000/2050
# 2000/2050
# l3
# 0/2562
# 1000/2562
# 2000/2562
# l4
# 0/1573
# 1000/1573
# l5
# 0/2579
# 1000/2579
# 2000/2579
# l6
# 0/1316
# 1000/1316
# l7
# 0/2800
# 1000/2800
# 2000/2800
# m1
# 0/832
# m2
# 0/620
# m3
# 0/2511
# 1000/2511
# 2000/2511
# m4
# 0/1522
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f4e7849ba314> in <module>
#      20
#      21         asyncs_i = pd.DataFrame({'cond': onset_i.cond,
# ---> 22                                  'asyncs': onset_i.time-near_onsets.time,})
#      23         master_asyncs = master_asyncs.append(asyncs_i)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1064         lvalues = left.values
#    1065         rvalues = right
# -> 1066         if isinstance(rvalues, ABCSeries):
#    1067             rvalues = rvalues.values
#    1068
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/dtypes/generic.py in _check(cls, inst)
#       7     @classmethod
#       8     def _check(cls, inst):
# ----> 9         return getattr(inst, attr, '_typ') in comp
#      10
#      11     dct = dict(__instancecheck__=_check, __subclasscheck__=_check)
#
# KeyboardInterrupt:

# %%
master_onsets = pd.read_csv(glob('../Pipeline/*.csv')[0])

# %%
master_onsets.to_csv('../master_onsets.csv',index=False)

# %%
def get_asyncs_fast(person, other):
    condition = person.cond[0]
    person_i = 0
    other_i = 0

    asyncs = pd.DataFrame()
    while ((person_i < len(person)) & (other_i < len(other))):
        onset_person = person.iloc[person_i].time
        onset_other = other.iloc[other_i].time
        asynchrony = onset_person - onset_other
        if (abs(asynchrony) < MIN_THRES):
            # append async
            asyncs = asyncs.append(pd.DataFrame({'cond': condition,
                                                 'asyncs': asynchrony}))
            # increment other_i
            other_i += 1
        elif (asynchrony > 0):
            # increment other_i
            other_i += 1
        else:
            # increment person_i
            person_i += 1
    
    return asyncs
